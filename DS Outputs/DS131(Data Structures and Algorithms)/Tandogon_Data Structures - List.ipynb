# %% [markdown]
# $\textbf{DS 131 - DATA STRUCTURES and ALGORITHMS} \\ \text{1Q SY2324}$
#
# $\text{Edgar M. Adina} \\ \textit{Instructor}$

# %% [markdown]
# ## <center> DATA STRUCTURES - LIST

# %% [markdown]
# We saw strings in the previous lesson that could hold a sequence of characters. Now, let’s see a more versatile sequential data structure in Python - Lists. The way to define it is to use a pair of brackets [ ], and the elements within it are separated by commas. A list could hold any type of data: numerical, or strings or other types. For example:

# %%
list_1 = [1, 2, 3]
list_1
# Out:
# [1, 2, 3]

# %%
list_2 = ['Hello', 'World']
list_2
# Out:
# ['Hello', 'World']

# %% [markdown]
# We could put mixed types in the list as well

# %%
list_3 = [1, 2, 3, 'Apple', 'orange']
list_3
# Out:
# [1, 2, 3, 'Apple', 'orange']

# %% [markdown]
# We can also nest the lists, for example:

# %%
list_4 = [list_1, list_2]
list_4
# Out:
# [[1, 2, 3], ['Hello', 'World']]

# %% [markdown]
# The way to retrieve the element in the list is very similar to the strings, see the following figure for the index

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example:** Get the 3rd element in list_3

# %%
list_3[3]
# Out:
# 'Apple'

# %% [markdown]
# **Example:** Get the first 3 elements in list_3

# %%
list_3[:3]
# Out:
# [1, 2, 3]

# %% [markdown]
# **Example:** Get the last element in list_3

# %%
list_3[-1]
# Out:
# 'orange'

# %% [markdown]
# **Example:** Get the first list from list_4.

# %%
list_4[0]
# Out:
# [1, 2, 3]

# %% [markdown]
# Similarly, we could get the length of the list by using the len function.

# %%
len(list_3)

# %% [markdown]
# We can also concatenate two lists by simply using a + sign.

# %% [markdown]
# **Example:** Add list_1 and list_2 to one list.

# %%
list_1 + list_2
# Out:
# [1, 2, 3, 'Hello', 'World']

# %% [markdown]
# New items could be added to an existing list by using the append method from the list.

# %%
list_1.append(4)
list_1
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# *Note:* The append function operate on the list itself as shown in the above example, 4 is added to the list. But in the list_1 + list_2 example, list_1 and list_2 won’t change. You can check list_2 to verify this.
#
# We could also insert or remove element from the list by using the methods insert and remove, but they are also operating on the list directly.

# %%
list_1.insert(2,'center')
list_1
# Out:
# [1, 2, 'center', 3, 4]

# %% [markdown]
# *Note:* Using the remove method will only remove the first occurrence of the item (read the documentation of the method). There is another way to delete an item by using its index - function del.

# %%
del list_1[2]
list_1
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# We could also define an empty list and add in new element later using append method. It is used a lot in Python when you have to loop through a sequence of items, we will learn more later in the iteration chapter.

# %% [markdown]
# **Example:** Define an empty list and add values 5 and 6 to the list.

# %%
list_5 = []
list_5.append(5)
list_5
# Out:
# [5]

# %%
list_5.append(6)
list_5
# Out:
# [5, 6]

# %% [markdown]
# We could also quickly check if an element is in the list using the operator *in*.

# %% [markdown]
# **Example:** Check if number 5 is in the *list_5*.

# %%
5 in list_5
# Out:
# True

# %% [markdown]
# Using the *list* function, we could turn other sequence items into a list.

# %% [markdown]
# **Example:** Turn the string ‘Hello World’ into a list of characters.

# %%
list('Hello World')
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %% [markdown]
# ### <center> EXERCISE

# %% [markdown]
# **1.** Assign list [1, 8, 9, 15] to a variable *list_a* and insert 2 at index 1 using the **insert** method. Append 4 to the *list_a* using the **append** method.

# %%
list_a = [1, 8, 9, 15]

# %%
list_a.insert(1, 2)

# %%
list_a.append(4)

# %%
print(list_a)
# Out:
# [1, 2, 8, 9, 15, 4]

# %% [markdown]
# **2.** Turn ‘Data Science is fun!’ to a list.

# %%
original_string = 'Data Science is fun!'

# %%
char_list = [char for char in original_string]

# %%
print(char_list)
# Out:
# ['D', 'a', 't', 'a', ' ', 'S', 'c', 'i', 'e', 'n', 'c', 'e', ' ', 'i', 's', ' ', 'f', 'u', 'n', '!']

# %%
#OR

# %%
list('Data Science is Fun!')
# Out:
# ['D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'F',
#  'u',
#  'n',
#  '!']
